# %% [markdown]
# <a href="https://colab.research.google.com/github/wcliao1962/2025_DL/blob/master/%E5%86%92%E9%9A%AA04_%E4%BA%92%E5%8B%95%E6%A8%A1%E5%BC%8F%E7%9A%84%E8%A4%87%E7%BF%92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. 讀入基本套件

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. 定義一個函數，就能互動!

# %%
def bmi_cal(h, w):
    h = float(h)/100
    w = float(w)
    bmi = w/(h**2)
    message = f"你的 BMI 是 {bmi:.2f}。"
    print(message)

# %%
bmi_cal(165, 62)
# Out:
# 你的 BMI 是 22.77。

# %% [markdown]
# ## 3. 互動界面

# %%
from ipywidgets import interact_manual

# %%
interact_manual(bmi_cal, h="請輸入你的身高 (公分)", w="請輸入你的體重 (公斤)");
# Out:
# interactive(children=(Text(value='請輸入你的身高 (公分)', description='h'), Text(value='請輸入你的體重 (公斤)', description='w')…

# %% [markdown]
# # New Section
